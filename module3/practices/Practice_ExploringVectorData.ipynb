# %% [markdown]
# # Practice Exploring Vector Data
#
# For this practice, we will explore the following data sets:
#  * http://www.naturalearthdata.com/http//www.naturalearthdata.com/download/110m/cultural/ne_110m_admin_0_countries.zip
#     * [Read more here](http://www.naturalearthdata.com/downloads/110m-cultural-vectors/110m-admin-0-countries/)
#  * http://www.naturalearthdata.com/http//www.naturalearthdata.com/download/10m/cultural/ne_10m_populated_places.zip
#     * [Read more here](http://www.naturalearthdata.com/downloads/10m-cultural-vectors/10m-populated-places/)

# %% [markdown]
# ## Data Set 1:
#  * Download the ZIP files to your `module3/temp/` folder.
#  * Create `module3/temp/ne_admin_countries/` folder
#  * Change into `ne_admin_countries` folder and unzip the Country Borders data into the folder.
#    * Example files in folder after unpacking.
# ```BASH
# module3/temp]$ find ne_admin_countries/
# ne_admin_countries/
# ne_admin_countries/ne_110m_admin_0_countries.README.html
# ne_admin_countries/ne_110m_admin_0_countries.VERSION.txt
# ne_admin_countries/ne_110m_admin_0_countries.cpg
# ne_admin_countries/ne_110m_admin_0_countries.dbf
# ne_admin_countries/ne_110m_admin_0_countries.prj
# ne_admin_countries/ne_110m_admin_0_countries.shp
# ne_admin_countries/ne_110m_admin_0_countries.shx
# ```

# %%
## M3:P1:Cell01
# Add Your Code to Download the File
# -----------------------------------------

# %% [markdown]
# We then expect, if all went well, that we can load the file with the next cell.
#
# <span style="background:yellow">If you get any errors</span>, carefully resolve your issues until your directory structure under module 3 for the temp folder matches above!

# %%
#### TRY TO GET THIS CELL TO RUN WITHOUT CHANGES

import geopandas as gpd

countries = gpd.read_file('../temp/ne_admin_countries')

# %%
## M3:P1:Cell02
# Add Your Code to Inspect the GeoDataFrame
# -----------------------------------------
# Out:
#                                                             0  \
# ABBREV                                                   Afg.
# ABBREV_LEN                                                  4
# ADM0_A3                                                   AFG
# ADM0_A3_IS                                                AFG
# ADM0_A3_UN                                                -99
# ADM0_A3_US                                                AFG
# ADM0_A3_WB                                                -99
# ADM0_DIF                                                    0
# ADMIN                                             Afghanistan
# BRK_A3                                                    AFG
# BRK_DIFF                                                    0
# BRK_GROUP
# BRK_NAME                                          Afghanistan
# CONTINENT                                                Asia
# ECONOMY                             7. Least developed region
# ...

# %% [markdown]
# Review the columns and such of the data frame.
# Answer the following Questions:
#  1. What is the datatype of the geometric elements within this geospatial data file?
#  1. What is the name of the column for the geometric elements?
#  1. What do you expect to be relevant fields for performing selection operations on the data frame?

# %% [raw]
# ## M3:P1:Cell03
# # Enter your answers below
# # -----------------------------------------
#
#
# 1)
#
#
#
#
# 2)
#
#
#
# 3)

# %%
# Plot the data!

import matplotlib.pyplot as plt
# %matplotlib inline
countries.plot(figsize=(15,15))

# %% [markdown]
# #### Review the plot above
#
# What can you tell from the rendering of the data?  Specifically, answer these questions:
#   1. What do the plot axis equate to relative to the coordinate system (e.g., X-axis is ... )?
#   1. What are the coordinate system bounds and does the map adequately reflect these limits?
#   1. What happens conceptually at -180 and 180 on the X-Coordinate?
#   1. What happens conceptually at the top and bottom of the plot, relative to the Y-Coordinate?

# %% [raw]
# ## M3:P1:Cell04
# # Enter your answers below
# # -----------------------------------------
#
#
# 1)
#
#
#
#
# 2)
#
#
#
# 3)
#
#
#
# 4)

# %% [markdown]
# Recall what you learned about coordinate reference systems (CRS).
#
# Let's examine the CRS:

# %%
print(countries.crs)
# Out:
# {'init': 'epsg:4326'}

# %% [markdown]
# #### Task: Create a new GeoDataFrame as a transform of the data to spatial reference 3275 and then plot it.

# %%
## M3:P1:Cell05
# -----------------

transformed = # add code here


transformed.plot(figsize=(15,15))

# %% [markdown]
# ## Select and render the following:
#  1. Countries in Continent North America
#  1. Brazil
#  1. Countries in Southern Asia Subregion

# %%
## M3:P1:Cell06
# -----------------

americas = # add code here


americas.plot(figsize=(15,15))

# %%
## M3:P1:Cell07
# -----------------

brazil = # add code here


brazil.plot(figsize=(15,15))

# %%
## M3:P1:Cell08
# -----------------


south_asia = # add code here

south_asia.plot(figsize=(15,15))

# %% [markdown]
# ### Task: Compute the area of Brazil in Square Kilometers
#
# **HINT** Transform to an appropriate metric unit CRS. Examples may include:
#  * 5531
#  * 5537
#  * 5641
#
# Consult the Internet to find sources for potential relevant spatial reference IDs (SRID).
#
# Evaluate a couple and see what is closest to the reported area in square kilometers based on an Internet resource (Wikipedia or Google).
#
# In the next cells, you will list the EPSG codes you tried, and which ones were closest to your researched result.
# Leave the closest measuring SRID as the one in the code for submission.

# %%
## M3:P1:Cell09
# -----------------

brazil =  # add code here

projected_area = (<add_code_here> / (1000000.0)).iloc[0]

print("Area of Brazil is {0:.0f} square kilometers".format(projected_area))
# Out:
# Area of Brazil is 8604233 square kilometers

# %% [markdown]
# ##### Task: A) List the area in Square KM and the source, B) along with all the EPSG you tried and which one was most accurate.

# %% [raw]
# ## M3:P1:Cell10
# #  Enter your answers below
# # ------------------------------
#
# A)
#
#
#
#
# B)

# %% [markdown]
# ##### Now measure the perimeter of the country!

# %%
## M3:P1:Cell11
# -----------------

projected_perimeter = # add code here


print("Perimiter of Brazil is {0:.0f} kilometers".format(projected_perimeter))
# Out:
# Perimiter of Brazil is 17435 kilometers

# %% [markdown]
# ## Data Set 2:
#  * Download the ZIP file to your `module3/temp/` folder.
#  * Create `module3/temp/ne_pop_places/` folder
#  * Change into `ne_pop_places` folder and unzip the Populated Places data into the folder.
#    * Example files in folder after unpacking.
# ```BASH
# module3/temp]$ find ne_pop_places/
# ne_pop_places/
# ne_pop_places/ne_10m_populated_places.README.html
# ne_pop_places/ne_10m_populated_places.VERSION.txt
# ne_pop_places/ne_10m_populated_places.cpg
# ne_pop_places/ne_10m_populated_places.dbf
# ne_pop_places/ne_10m_populated_places.prj
# ne_pop_places/ne_10m_populated_places.shp
# ne_pop_places/ne_10m_populated_places.shx
# ```
# The load the file into a new Geo Data Frame

# %%
## M3:P1:Cell11
#  Add download code here if needed
# ---------------------

# %% [markdown]
# #### Load and Examine the data!

# %%
## M3:P1:Cell12
#  Load into a GeoPanda DF

import geopandas as gpd
pop_pl = gpd.read_file('../temp/ne_pop_places')

# add more code here
# ---------------------
# Out:
#                                                             0  \
# ADM0CAP                                                     0
# ADM0NAME                                              Uruguay
# ADM0_A3                                                   URY
# ADM1NAME                                              Colonia
# ADMIN1_COD                                                  4
# CAPALT                                                      0
# CAPIN
# CHANGED                                                     4
# CHECKME                                                     0
# CITYALT
# COMPARE                                                     0
# DIFFASCII                                                   0
# DIFFNOTE    Added missing admin-1 capital. Population from...
# ELEVATION                                                   0
# FEATURECLA                                    Admin-1 capital
# FEATURE_CL                                                  P
# ...

# %%
# Plot the data!

import matplotlib.pyplot as plt
# %matplotlib inline
pop_pl.plot(figsize=(15,15))

# %% [markdown]
# ### Use your Pandas experience and sum the `GN_POP` field for each country (`SOV0NAME`)

# %%
## M3:P1:Cell13
#  Group By ?
# ---------------------

country_populations = # Add Code Here

print(country_populations)
# Out:
# SOV0NAME
# Afghanistan                     5267025.0
# Albania                         1142123.0
# Algeria                         5422551.0
# Andorra                            7890.0
# Angola                          4204657.0
# Antigua and Barbuda               24226.0
# Argentina                      27352981.0
# Armenia                         1418722.0
# Australia                      16484773.0
# Austria                         2513711.0
# Azerbaijan                      2044803.0
# Bahamas, The                     227940.0
# Bahrain                          147074.0
# Bangladesh                     18859439.0
# Barbados                           2971.0
# Belarus                         4692199.0
# Belgium                         2502720.0
# Belize                           114640.0
# Benin                           1734536.0
# Bhutan                            98676.0
# Bolivia                         4466671.0
# Bosnia and Herzegovina          1365611.0
# ...

# %% [markdown]
# #### Task: Filter down to just Brazil populated places!

# %%
## M3:P1:Cell14
#  Pandas filtered selections
# ---------------------


brazil_places = # Add Code Here
# Out:
#                                                       1453  \
# ADM0CAP                                                  0
# ADM0NAME                                            Brazil
# ADM0_A3                                                BRA
# ADM1NAME                                          Maranhão
# ADMIN1_COD                                              13
# CAPALT                                                   0
# CAPIN
# CHANGED                                                  4
# CHECKME                                                  0
# CITYALT
# COMPARE                                                  0
# DIFFASCII                                                0
# DIFFNOTE                         Population from GeoNames.
# ELEVATION                                                0
# FEATURECLA                                 Populated place
# FEATURE_CL                                               P
# FEATURE_CO                                             PPL
# ...

# %% [markdown]
# ### Plotting with Overplots
#
# Read more about: http://geopandas.org/mapping.html#maps-with-layers
#
#  1. Plot the Brazil country border as a white shape with a blue border.
#  1. Plot the location of Brazil populated places with red circles.

# %%
## M3:P1:Cell15
#  Load into a GeoPanda DF
# ---------------------

# %% [markdown]
# Did this do what you expected?
# Why not?
#
#
# #### This is the expected output:
#
# ![brazil_pp.png MISSING](../images/brazil_pp.png)
#
#
# <span style="background:yellow">**Make sure you fix it before submission.**</span>

# %% [markdown]
# # Save your notebook
#
# ## The File > Save and Halt
